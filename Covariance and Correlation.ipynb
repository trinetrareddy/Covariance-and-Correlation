# %% [raw]
# ### Understanding Covariance and Pearson Correlation
#
# **Covariance** measures how two features vary together. It is calculated by taking the sum of the product of the differences of each feature from its mean, divided by the number of data points (N for a population, or \(n-1\) for a sample).
#
# Covariance can range from \(-\infty\) to \(+\infty\).
# - A positive covariance indicates that the features are positively correlated (they increase or decrease together).
# - A negative covariance suggests that the features are inversely correlated (one increases as the other decreases).
# - A covariance of zero means there is no correlation between the features.
#
# While covariance helps us understand the relationship between two features, it doesn't provide a standardized measure. For example, a covariance of 100 and 1000 are hard to compare directly; we can't tell which indicates a stronger relationship.
#
# This is where the **Pearson correlation coefficient** comes in. Pearson correlation standardizes the covariance by dividing it by the product of the standard deviations of the two features. This normalizes the values between \(-1\) and \(1\), making it easier to understand the strength and direction of the relationship:
# - A value closer to \(1\) indicates a strong positive correlation.
# - A value closer to \(-1\) indicates a strong negative correlation.
# - A value around \(0\) indicates no correlation.
#
# However, it's important to note that **Pearson correlation** only captures **linear relationships**. It won't accurately represent non-linear correlations or more granular relationships between features.
#
# To address this, we use the **Spearman correlation coefficient**, which measures the strength and direction of the association between two ranked variables. It is calculated using the rank of the data points rather than the raw data, specifically by dividing the rank covariance by the product of the rank standard deviations of each feature.
#
# **Spearman correlation** works well for **non-linear relationships** and provides a more accurate measure of association when the relationship between the variables isn't purely linear. It is particularly useful for capturing more complex, monotonic relationships that Pearson might miss.
#
# By understanding both Pearson and Spearman correlations, we can better analyze and interpret the relationships between different sets of features, whether they are linear or non-linear.

# %% [markdown]
# # Pearson correlation

# %% [markdown]
# ![Screenshot 2024-08-31 at 11.20.00 PM.png](attachment:64338211-682c-45f4-bc1c-9032a60d9f40.png)

# %% [markdown]
# # Pearson correlation vs Spearman correlation

# %% [markdown]
# ![Screenshot 2024-08-31 at 11.07.13 PM.png](attachment:ab4dee23-852d-4170-b7aa-7fd75249d046.png)

# %% [raw]
# Non-monotonic relationships are important to identify because they indicate a more complex interaction between variables, which might not be well captured by simple linear models or correlations like Pearson correlation.

# %% [raw]
# SciPy is a powerful library for scientific computing in Python, providing tools and functions across various domains, including mathematics, science, and engineering. Its integration with NumPy and other scientific libraries makes it an essential tool for data analysis, machine learning, and other technical applications.

# %%
import numpy as np
from scipy.stats import pearsonr, spearmanr

# Sample data
X = np.array([1, 2, 3, 4, 5])
Y_linear = np.array([2, 4, 6, 8, 10])  # Perfect linear relationship
Y_non_linear = np.array([1, 4, 9, 16, 25])  # Quadratic relationship
Y_non_monotonic = np.array([2, 1, 4, 1, 2])  # Non-monotonic relationship

# Function to calculate covariance
def calculate_covariance(x, y):
    n = len(x)
    covariance = np.sum((x - np.mean(x)) * (y - np.mean(y))) / (n - 1)
    return covariance

# Covariance calculation
cov_linear = calculate_covariance(X, Y_linear)
cov_non_linear = calculate_covariance(X, Y_non_linear)
cov_non_monotonic = calculate_covariance(X, Y_non_monotonic)

print("Covariance (Linear):", cov_linear)
print("Covariance (Non-Linear):", cov_non_linear)
print("Covariance (Non-Monotonic):", cov_non_monotonic)

# Pearson correlation calculation
pearson_corr_linear, _ = pearsonr(X, Y_linear)
pearson_corr_non_linear, _ = pearsonr(X, Y_non_linear)
pearson_corr_non_monotonic, _ = pearsonr(X, Y_non_monotonic)

print("Pearson Correlation (Linear):", pearson_corr_linear)
print("Pearson Correlation (Non-Linear):", pearson_corr_non_linear)
print("Pearson Correlation (Non-Monotonic):", pearson_corr_non_monotonic)

# Spearman correlation calculation
spearman_corr_linear, _ = spearmanr(X, Y_linear)
spearman_corr_non_linear, _ = spearmanr(X, Y_non_linear)
spearman_corr_non_monotonic, _ = spearmanr(X, Y_non_monotonic)

print("Spearman Correlation (Linear):", spearman_corr_linear)
print("Spearman Correlation (Non-Linear):", spearman_corr_non_linear)
print("Spearman Correlation (Non-Monotonic):", spearman_corr_non_monotonic)
# Out:
# Covariance (Linear): 5.0
# Covariance (Non-Linear): 15.0
# Covariance (Non-Monotonic): 0.0
# Pearson Correlation (Linear): 1.0
# Pearson Correlation (Non-Linear): 0.981104910251593
# Pearson Correlation (Non-Monotonic): 0.0
# Spearman Correlation (Linear): 0.9999999999999999
# Spearman Correlation (Non-Linear): 0.9999999999999999
# Spearman Correlation (Non-Monotonic): 0.0
